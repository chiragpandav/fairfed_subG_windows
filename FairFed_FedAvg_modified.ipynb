# %% [markdown]
# ======FairFed============
#
# -> Init Models for clients
#
# -> Get statistics of the dataset
#
# -> start training
#
#       -> for each round-> assigning agg global model to all clients
#
# -> for each client
#
#         > Update its weights based on local and global fairness
#
#         > store it
# -> SecAgg applied on the server side
#
# Total data for weights: WM + WW + BM + BW
#
# Training data: Datasplit using Sub_grp
#
# Validation on Sub_grp

# %%
import pandas as pd
import time
import numpy as np
import copy
import glob
import sys, os
import torch
import torch.nn as nn
import torch.utils.data as data_utils
from sklearn.metrics import precision_score, recall_score
import pickle
from sklearn import preprocessing
import torch.optim as optim
from sklearn.preprocessing import LabelEncoder
from folktables import ACSDataSource, ACSEmployment,ACSIncome
import matplotlib.pyplot as plt
import torch.nn.functional as F
from tqdm import tqdm
from sklearn.metrics import roc_curve
from sklearn.model_selection import StratifiedKFold, train_test_split
from torchvision import models
from torchsummary import summary
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score
import os
from scipy.stats import multivariate_normal
import torch, random, copy, os
from collections import OrderedDict
import shutil

# %% [markdown]
# # data preparation

# %%
import torch

if torch.cuda.is_available():
    print("CUDA is available.")
else:
    # CUDA is not available
    print("CUDA is not available. Running on CPU.")
# Out:
# CUDA is not available. Running on CPU.

# %%
class DeepNet(nn.Module):
    def __init__(self):
        super().__init__()
        # 14 : input shape
        # 9-> we have 9 columns in data 
        self.layer1 = nn.Linear(14, 512)
        self.act1 = nn.ReLU()
        self.dropout1 = nn.Dropout(p=0.5)
        self.layer2 = nn.Linear(512, 256)
        self.act2 = nn.ReLU()
        self.layer3 = nn.Linear(256, 60)
        self.act3 = nn.ReLU()
        self.output = nn.Linear(60, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.act1(self.layer1(x))
        x = self.dropout1(x)
        x = self.act2(self.layer2(x))
        x = self.act3(self.layer3(x))
        x = self.sigmoid(self.output(x))
        return x

# %% [markdown]
# # assigning Models

# %%
class AssignModel:
    def __init__(self, global_model_base_path, selected_clients,algo="FF"):      
        self.global_model_path = f"{global_model_base_path}/global_model_{algo}_OE.pt"
        self.selected_clients = selected_clients
        
#         self.models_directory = "models"
#         os.makedirs(self.models_directory, exist_ok=True)
        
    def save_global_model(self, model):
        torch.save(model.state_dict(), self.global_model_path)

    def save_client_models(self, model):
        for client_id in self.selected_clients:
            client_model_path= os.path.join(os.getcwd(), "models")     
            client_model_path= f"{client_model_path}/client_{client_id}_model.pth"
#             client_model_path = f"/home/chiragapandav/Downloads/Hiwi/Improving-Fairness-via-Federated-Learning/FedFB/models/client_{client_id}_model.pth"
            torch.save(model.state_dict(), client_model_path)

# %%
class Client:
    def __init__(self, batch_size):
        self.client_id: int = None
        self.valset: DataLoader = None
        self.trainset: DataLoader = None
        self.testset: DataLoader = None
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")         
        self.model = DeepNet().to(self.device)
        self.learning_rate=0.001
        self.criterion = torch.nn.BCELoss()
        self.optimizer: torch.optim.Optimizer = torch.optim.Adam(
            self.model.parameters(), lr=self.learning_rate
        )
        
        self.Batch = batch_size
        self.fainess_score=0
        self.local_epochs=5
        self.client_df = pd.DataFrame()
        self.selected_clients=[0,1,2,3]

        self.client_fairness=0
        self.global_fairness=0
        
#         self.model_dir="/home/chiragapandav/Downloads/Hiwi/Improving-Fairness-via-Federated-Learning/FedFB/models/"

        self.model_dir = os.path.join(os.getcwd(), "models")

        #data_random_split_fairFed
        #data_fairFed
#         self.data_dir="/home/chiragapandav/Downloads/Hiwi/Improving-Fairness-via-Federated-Learning/FedFB/data_subGsplit_fairFed/"
        self.data_dir = os.path.join(os.getcwd(), "data_subGsplit_fairFed")
        
    def get_client_local_dataset(self):                
        
        with open( self.data_dir+"/clients_training.pkl", "rb") as f:
            self.trainset = pickle.load(f)
            
        with open( self.data_dir+"/clients_validation.pkl", "rb") as f:
            self.valset = pickle.load(f)
         
        with open( self.data_dir+"/clients_testing_wrong.pkl", "rb") as f:
            self.testset  = pickle.load(f)

        self.trainset = self.trainset[self.client_id]
        self.valset = self.valset[self.client_id]       
        self.testset = self.testset[self.client_id]

    def get_stats(self):
        # 1 male 0 female
        total_pr_Y1_A0 = 0
        total_pr_Y1_A1 = 0
        len_of_entire_data=0
        
        for client_id in self.selected_clients:
            self.client_id=client_id
            self.get_client_local_dataset()
            len_of_entire_data+=len(self.trainset.dataset)
            for inputs, labels, A in self.trainset:
                pr_Y1_A1 = torch.sum((labels == 1) & (A == 1)).item()
                pr_Y1_A0 = torch.sum((labels == 1) & (A == 0)).item()
                # len_of_entire_data+=len(self.trainset)
                total_pr_Y1_A1 += pr_Y1_A1
                total_pr_Y1_A0 += pr_Y1_A0
                
            # print("len_of_entire_data::",len_of_entire_data)
            # print("pr_Y1_A1 and pr_Y1_A0",total_pr_Y1_A1,"::",total_pr_Y1_A0)
            # print(total_pr_Y1_A0/len(self.trainset)," , ",print(total_pr_Y1_A1/len(self.trainset)))        
        
        return [total_pr_Y1_A1/len_of_entire_data,total_pr_Y1_A0/len_of_entire_data]
        
    def calculate_fairness_client(self,client_id,y_hat, A, Y,server_acc,client_acc,len_client_data):
        # Calculate counts using torch.sum
        y_hat, A, Y = y_hat.to(self.device), A.to(self.device), Y.to(self.device)

        # 1: Male, 0: Female
        predict_Y_male = torch.sum((y_hat[(A == 1) & (Y == 1)] == 1)).item()
        predict_Y_female = torch.sum((y_hat[(A == 0) & (Y == 1)] == 1)).item()
        
        count_Y_male = torch.sum((Y[(A == 1) & (Y == 1)] == 1)).item()
        count_Y_female = torch.sum((Y[(A == 0) & (Y == 1)] == 1)).item()
    
        
        fairness_score=0
        #this assingment could be wrong
        prob_Y_male=0
        prob_Y_female=0
        diff_of_acc=0
        # Calculate probabilities
        if count_Y_male > 0: 
            prob_Y_male = predict_Y_male / count_Y_male
            
        elif count_Y_female > 0:
            prob_Y_female = predict_Y_female / count_Y_female

        else:
            # Cal sever_acc from client using Eq.
            total_len_data=sum(len_client_data)   
            temp_server_acc=0
            # get global acc
            for i in range(len(self.selected_clients)):
                temp_server_acc+=client_acc[i]*(len_client_data[i]/total_len_data)
                
            diff_of_acc = abs(client_acc[client_id]-temp_server_acc)
            
        fairness_score = prob_Y_male - prob_Y_female
        # print("\n  fairness_score",fairness_score)
            
        # print(" client fairness_score",fairness_score)
            
        return  fairness_score,diff_of_acc

    def calculate_ser_fairness(self,client_id,y_hat, A, Y,statistics,server_acc,client_acc,len_client_data):
        # print("calculate_ser_fairness statistics",statistics)
        y_hat, A, Y = y_hat.to(self.device), A.to(self.device), Y.to(self.device)

        # for individual clients!
        #Pr(Ŷ=1|A=1, Y=1)  #male      
        predict_Y_male = torch.sum((y_hat[(A == 1) & (Y == 1)] == 1)).item() #get total
        #Pr(A=0, Y=1)
        count_Y_male = torch.sum((A == 1) & (Y == 1)).item() 
        count_male = torch.sum(A == 1).item()
        

        #Pr(Ŷ=1|A=0, Y=1)  #Female      
        predict_Y_female = torch.sum((y_hat[(A == 0) & (Y == 1)] == 1)).item()  #get total
        #Pr(A=1, Y=1)
        count_Y_female = torch.sum((A == 0) & (Y == 1)).item()
        count_female = torch.sum(A == 0).item()
        
        if count_Y_male>0 and count_male>0:
            # print("if_male")
            step_2_eq_male=count_Y_male/count_male            
            predict_Y_male=predict_Y_male/count_Y_male #Pr(Ŷ=1|A=0, Y=1)            
            step_3_male=((predict_Y_male * step_2_eq_male)/statistics[0]) 
        else:
            # print("else_male")
            step_3_male=0
            
        if count_Y_female>0 and count_female>0 :
            # print("if_female")
            step_2_eq_female=count_Y_female/count_female
            predict_Y_female=predict_Y_female/count_Y_female   #Pr(Ŷ=1|A=1, Y=1)
            step_3_female= ((predict_Y_female * step_2_eq_female)/statistics[1])
        else:
            # print("else_female")
            step_3_female=0

        temp_fairness_server=step_3_male-step_3_female
            
        return temp_fairness_server

    def get_client_weights(self):        
        # self.client_id = client_id
        
        clients_weights=[]
        clients_weights_val=[]
        for client_id in self.selected_clients:
            self.client_id=client_id
            self.get_client_local_dataset()
            clients_weights.append(len(self.trainset.dataset))
            clients_weights_val.append(len(self.valset.dataset))

        return clients_weights,clients_weights_val
        
    def train_FA(self, client_id: int, model_path,learning_rate=0.001,num_epochs=5):
        self.model.load_state_dict(torch.load(model_path,map_location=self.device))
        
        self.model.train()
        for epoch in range(num_epochs):
            print("epoch",epoch)
            for x, y,z in self.trainset:
                x, y = x.to(self.device), y.to(self.device)
                logits = self.model(x)
                loss = self.criterion(logits, y)
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()
                
        # models_directory = "/home/chiragapandav/Downloads/Hiwi/Improving-Fairness-via-Federated-Learning/FedFB/models/"
        model_path_1 = os.path.join(self.model_dir, f"client_{client_id}_model.pth")          
        torch.save(self.model.state_dict(), model_path_1)
        print(f"client_{client_id} is updated \n\n\n" )
                
        return list(self.model.state_dict().values()), len(self.trainset.dataset)
       
        
    def train_FF(self, client_id: int, model_path,statistics,server_acc,clients_acc,len_client_data, num_epochs=5, learning_rate=0.001):
        self.client_id = client_id
        self.get_client_local_dataset()
        # print("len_of_entire_data FF",len(self.trainset))
        # Define loss function and optimizer
        
        self.fainess_score=0
      
        self.model.load_state_dict(torch.load(model_path,map_location=self.device))
        
        self.model.train()
        for epoch in range(num_epochs):
            # Set the model to training mode

            for inputs, labels, sens in self.trainset:
                
                inputs, labels = inputs.to(self.device), labels.to(self.device)
                outputs = self.model(inputs).to(self.device)
                loss = self.criterion(outputs, labels.float())
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

            # Calculate and print the training accuracy for this epoch (optional)
            
            correct = 0
            total = 0
            size = 0
            loss = 0
            correct = 0
            total = 0
            predicted_labels = []
            true_labels = []
            final_fairness=[]
            final_fairness_server=[]
            
            with torch.no_grad():
                print("======Validation========")
                for inputs, labels,sens in self.valset:
                    inputs, labels = inputs.to(self.device), labels.to(self.device)
                    
                    outputs = self.model(inputs)
                    loss += self.criterion(outputs, labels)
                    
                        
                    predicted = outputs > 0.5

                    predicted_labels.extend(predicted.cpu().numpy())
                    true_labels.extend(labels.cpu().numpy())                   
                    
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()                   

            loss = loss / len(self.valset)        
            acc = correct/total
 
            fairNess_per_batch,diff_of_acc=self.calculate_fairness_client(self.client_id,torch.round(outputs).squeeze(), sens.squeeze(), labels.squeeze(),
                                                       server_acc,
                                                       clients_acc,
                                                       len_client_data)
            final_fairness.append(fairNess_per_batch)
            self.fainess_score=np.mean(final_fairness)

            #this is needed for Eq.7: global fairness
            fairNess_per_batch_server=self.calculate_ser_fairness(self.client_id,torch.round(outputs).squeeze(), sens.squeeze(), labels.squeeze(),
                                                                  statistics,
                                                                  server_acc,
                                                                  clients_acc,
                                                                  len_client_data)
            final_fairness_server.append(fairNess_per_batch_server)            
            ser_score=np.mean(final_fairness_server)
                        
            precision = precision_score(true_labels, predicted_labels,zero_division=0.0)            
            recall = recall_score(true_labels, predicted_labels)
            
            # accuracy = 100 * correct / total
            print(f"Epoch {epoch+1}/{num_epochs}, Val Accuracy: {acc:.5f}, Val Fairness: {self.fainess_score:.5f}, Val Recall: {recall:.5f}")

            # print(f"Epoch {epoch+1}/{num_epochs}, Val Accuracy: {acc:.5f}")
            # print(f"Epoch {epoch+1}/{num_epochs}, Val Fairness: {self.fainess_score:.5f}")
            # print(f"Epoch {epoch+1}/{num_epochs}, Val Recall: {recall:.5f}")


        # Optionally, save the trained model parameters
        #store model client model
        # models_directory = "/home/chiragapandav/Downloads/Hiwi/Improving-Fairness-via-Federated-Learning/FedFB/models/"
        model_path_1 = os.path.join(self.model_dir, f"client_{client_id}_model.pth")          
        
        torch.save(self.model.state_dict(), model_path_1)
        
        print(f"client_{client_id} is updated and its fairness score wrt global_model {ser_score} \n\n\n" )

        
        return list(self.model.state_dict().values()), len(self.trainset.dataset),self.model.state_dict(), self.fainess_score, ser_score

    @torch.no_grad()
    def client_evaluate(self, val=False):
        
        size = 0
        loss = 0
        correct = 0
        total = 0
        predicted_labels = []
        true_labels = []
        len_of_data=[]
        all_client_acc=[]
        
        # models_directory = "/home/chiragapandav/Downloads/Hiwi/Improving-Fairness-via-Federated-Learning/FedFB/models/"
                 
        for client_id in self.selected_clients:
            
            # to get the client specific split
            
            self.client_id=client_id
            self.get_client_local_dataset()
            
            model_path = os.path.join(self.model_dir, f"client_{client_id}_model.pth")            
        
            self.model.load_state_dict(torch.load(model_path,map_location=self.device))

            self.model.eval()

            # for inputs, targets,sens in self.testset:
            for inputs, targets,sens in self.valset:
                
                inputs, targets = inputs.to(self.device), targets.to(self.device)
                
                outputs = self.model(inputs)
                loss += self.criterion(outputs, targets)
                predicted = outputs > 0.5
                
                predicted_labels.extend(predicted.cpu().numpy())
                true_labels.extend(targets.cpu().numpy())
                
                total += targets.size(0)
                correct += (predicted == targets).sum().item()
                
                len_of_data.append(len(self.testset))
            
            loss = loss / len(self.testset)
            acc = correct / total
            all_client_acc.append(acc)
                        
            precision = precision_score(true_labels, predicted_labels,zero_division=0.0)
            
            recall = recall_score(true_labels, predicted_labels)
                            
        return loss, acc, precision, recall,len_of_data, all_client_acc

    
    @torch.no_grad()
    def server_evaluate(self,path,statistics,all_client_acc,len_of_data):

        # print("Global Model testing Starts")
        # print("kindly check the Path. Select it based on FedAvg Model")
        # print("warning: Test data has already been used")
        # temp_path_data="/home/chiragapandav/Downloads/Hiwi/Improving-Fairness-via-Federated-Learning/FedFB/"

        with open(self.data_dir+"/server_testing_client.pkl", "rb") as f:
            testset  = pickle.load(f)
                    
        # path="/home/chiragapandav/Downloads/Hiwi/Improving-Fairness-via-Federated-Learning/FedFB/models/global_model_2.pt"
        
        self.model.load_state_dict(torch.load(path,map_location=self.device))
        self.model.eval()
        size = 0
        loss = 0
        correct = 0
        total = 0
        predicted_labels = []
        true_labels = []
        final_fairness=[]

        self.testset=testset[1]
        for inputs, targets,sens in self.testset:
            
            inputs, targets = inputs.to(self.device), targets.to(self.device)
            
            outputs = self.model(inputs)
            loss += self.criterion(outputs, targets)
            predicted = outputs > 0.5
            
#            print("predicted",predicted)
            predicted_labels.extend(predicted.cpu().numpy())
            true_labels.extend(targets.cpu().numpy())
            
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
            
        
        loss = loss / len(self.testset)
        ser_acc = correct / total
        
        fairNess_per_batch=self.calculate_ser_fairness(self.client_id,torch.round(outputs).squeeze(), sens.squeeze(),
                                                                   targets.squeeze(),
                                                                  statistics,
                                                                  ser_acc,
                                                                  all_client_acc,
                                                                  len_of_data)

        final_fairness.append(fairNess_per_batch)
        fairness_global=np.mean(final_fairness)

        # print("loss: %f\n" % (loss))
        
        # print(f"Global Testing Accuracy: {ser_acc:.5%}")
        # print(f" Global Fairness: {fairness_global:.5f}%")
        precision = precision_score(true_labels, predicted_labels,zero_division=0.0)
        recall = recall_score(true_labels, predicted_labels)
        
        # print(f"Global Precision: {precision:.5%}")
        # print(f"Global Recall: {recall:.5%}")
        
        return loss, ser_acc, precision, recall,fairness_global

# %%
class Serverbase:
    def __init__ (self,model,beta):
        self.beta=beta
        self.model = model
        self.global_model=model
        self.num_rounds=2
        self.local_epoch=2
        self.optimizer=2
        self.lr=0.001
        
        self.batch_size=32
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 
    
        self.updated_params_cache = []
        self.weights_cache = []
        self.weights_total_cache=[]
        self.model_dict = []
        
        self.global_params_dict: OrderedDict[str : torch.Tensor] = None

        self.backbone=DeepNet
        _dummy_model = self.backbone()
        self.global_params_dict = OrderedDict(_dummy_model.state_dict())        

        self.temp_dir = os.path.join(os.getcwd(), "models")

#         self.temp_dir="/home/chiragapandav/Downloads/Hiwi/Improving-Fairness-via-Federated-Learning/FedFB/models/"

        self.fair_global_t_step=0
        self.fair_local_client=0   
        
        self.acc_clients=[]
        self.clients_id=[]
        self.precision_clients=[]
        self.recall_clients=[]
        
        self.global_acc=0
        self.fairness_diff=[]
        self.clients_weights=[]
        self.final_agg_weights_clients=[]
        self.selected_clients=[0,1,2,3]
        self.statistics=0
        self.clients_weights=[]

    def global_fairness(self,weights, temp_ser_fairness): 
        # all_clients_fairness is based on equation: 7
        # upper part is done in client class
        # self.statistics cal. pr(y=1,a=0)
        
        # print("global_fairness::",all_clients_fairness)
        # print("weights::",weights)
        
        weight_sum = sum(weights)  
        final_global_score=0
        
        for i in range(len(temp_ser_fairness)):
            temp=weights[i]/weight_sum            
            final_global_score+=temp*temp_ser_fairness[i]
            
        self.fair_global=final_global_score

    
        
    def fedAlgo(self, num_rounds = 2, local_epochs = 2, learning_rate = 0.001, optimizer = 'adam',algo="FF"):
        
        client = Client(batch_size=64)
       
        model_path=os.path.join(self.temp_dir, f"global_model_{algo}_OE.pt") 
         
        #before we start the training, we need statistics
        print("Getting data statistics....")
        self.statistics= client.get_stats()      
        
        print("self.statistics",self.statistics)

        #validation total  weights_cache = WW+ WM+ BM+ BW
        self.weights_total_cache, self.weights_cache=client.get_client_weights()
        
        print("Outer loop Before weights-1 (W/w):: ",self.weights_cache)
        weight_sum = sum(self.weights_cache)  
        self.weights_cache =  weight_sum/torch.tensor(self.weights_cache, device=self.device)
        
        print("Outer loop Before weights-1.1 (W/w):: ",self.weights_cache)
        
        # self.weights_total_cache, self.weights_cache=client.get_client_weights()
        
        
        for round_ in tqdm(range(num_rounds)):
  
            #each round we need empty lists
            self.updated_params_cache = []
            # self.weights_cache = []
            self.model_dict=[]
            self.clients_weights=[]
            self.final_agg_weights_clients=[]
            self.fair_global=0
            self.fair_local_all_client=[]
            temp_ser_fairness=[]

            print ("round::",round_)
            
             # clients and server acc for calculating Fairness whenever fairness_client is undefined
        
            loss_client, acc_client,precision, recall,len_of_data,all_client_acc = client.client_evaluate() 

            # to ge the acc of global model 
            loss_client, accuracy_server, pre_server, recall_ser,fairness_global = client.server_evaluate(model_path,self.statistics,all_client_acc,len_of_data)

            # print("all_client_acc:: ", all_client_acc)
            # print("self.weights_cache:",self.weights_cache)
            
            # print("self.weights_total_cache:",self.weights_total_cache)
            temp_global_acc = [acc * (weight / sum(self.weights_cache)) for acc, weight in zip(all_client_acc, self.weights_cache)]
            self.global_acc=sum(temp_global_acc)   
            self.acc_clients= all_client_acc
            
            for client_id in self.selected_clients:
                            
                
                # weight is length of dataset
                
                # Clone the model from server and assign it back to the clients                 

                if algo=="FF":
                    
                    updated_params, weight, model_dict_list,fairness_client,ser_fairness = client.train_FF(client_id, 
                                                                                                             model_path, 
                                                                                                             statistics=self.statistics,
                                                                                                             server_acc=accuracy_server,
                                                                                                             clients_acc=all_client_acc,
                                                                                                             len_client_data=len_of_data,
                                                                                                             num_epochs=local_epochs, 
                                                                                                             learning_rate=learning_rate)        
                                
                    
                    self.updated_params_cache.append(updated_params)
                    #not sure how to pass updated weights to next round
                    # self.weights_cache.append(weight)
                    self.model_dict.append(model_dict_list)
                    temp_ser_fairness.append(ser_fairness)
                                        
                    # self.global_acc=acc_server
                    self.fair_local_client=fairness_client
                    self.fair_local_all_client.append(fairness_client)
                
                if algo=="FA":
                    updated_params, weight, = client.train_FA(client_id, model_path,
                                                              num_epochs=local_epochs,
                                                              learning_rate=learning_rate)
                                                                                            
                                
                    # store it for SecAgg
                    self.updated_params_cache.append(updated_params)
                    # self.weights_cache.append(weight)
                    

            # print("temp_ser_fairness::",temp_ser_fairness)
            # print("global self.weights_cache::",self.weights_cache)
            self.global_fairness(self.weights_cache, temp_ser_fairness)

            print("for round", round_,", global fairness, accuracy, and recall are: ",self.fair_global,", ",
                                                                                  accuracy_server,", ",
                                                                                  recall_ser,"\n\n\n")
            
            if algo=="FF":
                # agg all the weights on serverside
                # Update the weights of each client
                self.aggregate_client_weight_FedFair_FedAVG(self.updated_params_cache,self.model_dict, self.weights_cache,self.acc_clients,
                                                            self.global_acc,self.fair_local_client,
                                                             self.fair_global, self.fair_local_all_client)
                
                
            elif algo=="FA":
                self.aggregate_parameters_FedAvg(self.updated_params_cache,self.weights_cache)
            else:
                print("--Choose Algo --")
                break
        
            
            torch.save(self.global_model.state_dict(), os.path.join(self.temp_dir, f"global_model_{algo}_OE.pt"),)

            
    @torch.no_grad()
    def aggregate_parameters_FedAvg(self, updated_params_cache, weights_cache):
        
        weight_sum = sum(weights_cache)          
        weights = torch.tensor(weights_cache, device=self.device) / weight_sum

        print("weight",weights)
        
        aggregated_params = []

        for params in zip(*updated_params_cache):
            aggregated_params.append(
                torch.sum(weights * torch.stack(params, dim=-1), dim=-1)
            )
        
        aggregated_model_params = {}
        global_state_dict_keys = list(self.global_model.state_dict().keys())
        
        for param_name, param_value in zip(global_state_dict_keys, aggregated_params):
            aggregated_model_params[param_name] = param_value


        # aggregated_model_params = {param_name: param_value for param_name, param_value in zip(self.global_model.state_dict().keys(), aggregated_params)}

        self.global_model.load_state_dict(aggregated_model_params)


    @torch.no_grad()
    def aggregate_client_weight_FedFair_FedAVG (self,updated_params_cache, model_dict_list ,weights_cache, acc_clients, global_acc,fairness_client,fairness_global,fairness_all_client):

        # weights = torch.tensor(weights_cache, device=self.device) / weight_sum

        # print("client and G acc",acc_clients," :: ", global_acc)
        # weight_sum = sum(weights_cache)  

        # temp=self.weights_cache
        # temp_list=[]
        # print(" Init weights::",weights_cache)
#         print("Before weights-1 (W/w):: ",self.weights_cache)
        
#         weight_sum = sum(self.weights_cache)  
#         self.weights_cache =  weight_sum/torch.tensor(self.weights_cache, device=self.device)
        # weights =  weight_sum/torch.tensor(self.weights_cache, device=self.device)
        
        
        print("Before weights -2 (W/w):: ",self.weights_cache)       
        # mean_fairness=np.mean(fairness_all_client)
        mean_acc=np.mean(acc_clients)                
        
        for i in range(len(self.weights_cache)):
            # Delta_t_C_i=abs(self.fair_global-fairness_all_client[i])
            # self.weights_cache[i]=temp[i]-self.beta*(Delta_t_C_i-mean_fairness)
            Delta_t_C_i=abs(global_acc-acc_clients[i])
            self.weights_cache[i]=self.weights_cache[i]-self.beta*abs(mean_acc-Delta_t_C_i)
                  
        print("After weights_:: ",self.weights_cache)
        
        # weights_cache=self.weights_cache
        weight_sum_2 = sum(self.weights_cache)  
        weights = torch.tensor(self.weights_cache, device=self.device) / weight_sum_2

        print("After weights_ Prob:: ",weights)
        
        aggregated_params = []

        for params in zip(*updated_params_cache):
            aggregated_params.append(
                torch.sum(weights * torch.stack(params, dim=-1), dim=-1)
            )
        
        aggregated_model_params = {}
        global_state_dict_keys = list(self.global_model.state_dict().keys())
        
        for param_name, param_value in zip(global_state_dict_keys, aggregated_params):
            aggregated_model_params[param_name] = param_value

        self.global_model.load_state_dict(aggregated_model_params)
  
    
    @torch.no_grad()
    def aggregate_parameters_FedAvg_updated(self, model_dict_list):        
        w_avg = copy.deepczopy(model_dict_list[0])
        for k in w_avg.keys():
            for i in range(1, len(model_dict_list)):
                w_avg[k] += model_dict_list[i][k]
            w_avg[k] = torch.div(w_avg[k], len(model_dict_list))
    
        self.global_model.load_state_dict(w_avg)

# %%
# FairFed "FF" and FedAVG "FA"

algo="FF" 

if algo=="FA":
    print("Comment out part1 and part2 def_fairFed ")
    
else:
    print("Algorithm is ", algo)
    

global_model_base_path = "models"

global_model_base_path = os.path.join(os.getcwd(), global_model_base_path)
    
# global_model_base_path = "/home/chiragapandav/Downloads/Hiwi/Improving-Fairness-via-Federated-Learning/FedFB/models"

shutil.rmtree(global_model_base_path)

os.mkdir(global_model_base_path)

selected_clients = [0, 1, 2, 3]

assigner = AssignModel(global_model_base_path, selected_clients,algo)

temp_model = DeepNet()  # Replace with your model instantiation
assigner.save_global_model(temp_model)
assigner.save_client_models(temp_model)


model = DeepNet()
server = Serverbase(model,beta=1)
server.fedAlgo(num_rounds=5,local_epochs=10,learning_rate = 0.001,algo=algo)
# Out:
# Algorithm is  FF
# Getting data statistics....
# self.statistics [0.21462357114702404, 0.1967327990189638]
# Outer loop Before weights-1 (W/w)::  [4620, 5495, 17309, 18242]
# Outer loop Before weights-1.1 (W/w)::  tensor([9.8844, 8.3105, 2.6383, 2.5033])
#   0%|                                                                                         | 0/5 [00:00<?, ?it/s]
# round:: 0
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.77900, Val Fairness: 0.71429, Val Recall: 0.64273
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.78203, Val Fairness: 0.71429, Val Recall: 0.66646
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.78788, Val Fairness: 0.85714, Val Recall: 0.73220
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.78636, Val Fairness: 0.57143, Val Recall: 0.64699
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.79545, Val Fairness: 0.71429, Val Recall: 0.71698
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.80346, Val Fairness: 0.85714, Val Recall: 0.74376
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.79307, Val Fairness: 0.85714, Val Recall: 0.82958
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.80952, Val Fairness: 0.71429, Val Recall: 0.75959
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.80823, Val Fairness: 0.71429, Val Recall: 0.72185
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.80281, Val Fairness: 0.85714, Val Recall: 0.80949
# client_0 is updated and its fairness score wrt global_model 2.329660238751148
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.76470, Val Fairness: -0.76000, Val Recall: 0.75471
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.77416, Val Fairness: -0.68000, Val Recall: 0.70111
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.77179, Val Fairness: -0.88000, Val Recall: 0.83921
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.78253, Val Fairness: -0.80000, Val Recall: 0.74022
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.77489, Val Fairness: -0.80000, Val Recall: 0.82762
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.78362, Val Fairness: -0.68000, Val Recall: 0.75519
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.78235, Val Fairness: -0.80000, Val Recall: 0.82231
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.79254, Val Fairness: -0.72000, Val Recall: 0.73588
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.79199, Val Fairness: -0.72000, Val Recall: 0.78127
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.78963, Val Fairness: -0.68000, Val Recall: 0.67890
# client_1 is updated and its fairness score wrt global_model -1.571120375617259
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.79456, Val Fairness: 0.81818, Val Recall: 0.78009
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.80559, Val Fairness: 0.72727, Val Recall: 0.78034
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.81079, Val Fairness: 0.72727, Val Recall: 0.75852
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.80704, Val Fairness: 0.63636, Val Recall: 0.73682
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.82079, Val Fairness: 0.81818, Val Recall: 0.82385
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.82483, Val Fairness: 1.00000, Val Recall: 0.82214
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.81986, Val Fairness: 0.72727, Val Recall: 0.76967
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.82604, Val Fairness: 0.90909, Val Recall: 0.81650
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.82760, Val Fairness: 0.63636, Val Recall: 0.78389
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.82177, Val Fairness: 0.72727, Val Recall: 0.77347
# client_2 is updated and its fairness score wrt global_model 1.285329786897185
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.75781, Val Fairness: -1.00000, Val Recall: 0.80009
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.77453, Val Fairness: -1.00000, Val Recall: 0.78591
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.77075, Val Fairness: -1.00000, Val Recall: 0.81267
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.77771, Val Fairness: -1.00000, Val Recall: 0.81643
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.76708, Val Fairness: -1.00000, Val Recall: 0.86923
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.77437, Val Fairness: -0.50000, Val Recall: 0.79488
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.75693, Val Fairness: -0.50000, Val Recall: 0.89918
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.78418, Val Fairness: -0.50000, Val Recall: 0.77882
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.77990, Val Fairness: -0.50000, Val Recall: 0.81773
# ======Validation========
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21932\960313446.py:242: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   weights = torch.tensor(self.weights_cache, device=self.device) / weight_sum_2
#  20%|████████████████                                                                | 1/5 [02:15<09:03, 135.75s/it]
# Epoch 10/10, Val Accuracy: 0.77881, Val Fairness: -0.50000, Val Recall: 0.85766
# client_3 is updated and its fairness score wrt global_model -2.5415182546749775
#
#
#
# for round 0 , global fairness, accuracy, and recall are:  tensor(0.2999) ,  0.6331183545407008 ,  0.0
#
#
#
# Before weights -2 (W/w)::  tensor([9.8844, 8.3105, 2.6383, 2.5033])
# After weights_::  tensor([9.2950, 7.7095, 2.0885, 1.9320])
# After weights_ Prob::  tensor([0.4421, 0.3667, 0.0993, 0.0919])
# round:: 1
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.81407, Val Fairness: 0.71429, Val Recall: 0.72672
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.80584, Val Fairness: 0.85714, Val Recall: 0.85332
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.81082, Val Fairness: 0.85714, Val Recall: 0.81132
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.81948, Val Fairness: 0.85714, Val Recall: 0.79671
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.81558, Val Fairness: 0.85714, Val Recall: 0.82410
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.81623, Val Fairness: 0.85714, Val Recall: 0.79489
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.81537, Val Fairness: 0.85714, Val Recall: 0.79793
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.82208, Val Fairness: 0.85714, Val Recall: 0.79367
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.81861, Val Fairness: 0.71429, Val Recall: 0.77906
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.81991, Val Fairness: 0.85714, Val Recall: 0.78332
# client_0 is updated and its fairness score wrt global_model 2.329660238751148
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.80273, Val Fairness: -0.84000, Val Recall: 0.78175
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.79927, Val Fairness: -0.88000, Val Recall: 0.82231
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.79727, Val Fairness: -0.76000, Val Recall: 0.79044
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.80036, Val Fairness: -0.72000, Val Recall: 0.75326
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.79818, Val Fairness: -0.76000, Val Recall: 0.78368
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.79672, Val Fairness: -0.76000, Val Recall: 0.75036
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.79581, Val Fairness: -0.76000, Val Recall: 0.77789
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.79454, Val Fairness: -0.60000, Val Recall: 0.71511
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.79672, Val Fairness: -0.76000, Val Recall: 0.79479
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.79217, Val Fairness: -0.92000, Val Recall: 0.84211
# client_1 is updated and its fairness score wrt global_model -2.125633449364527
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.81258, Val Fairness: 0.72727, Val Recall: 0.73266
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.82766, Val Fairness: 0.72727, Val Recall: 0.80583
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.82841, Val Fairness: 0.81818, Val Recall: 0.79971
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.83130, Val Fairness: 0.81818, Val Recall: 0.82741
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.81963, Val Fairness: 0.63636, Val Recall: 0.74933
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.83298, Val Fairness: 1.00000, Val Recall: 0.85487
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.82778, Val Fairness: 0.72727, Val Recall: 0.78463
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.83119, Val Fairness: 0.72727, Val Recall: 0.81062
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.83459, Val Fairness: 0.63636, Val Recall: 0.81062
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.83540, Val Fairness: 0.81818, Val Recall: 0.84212
# client_2 is updated and its fairness score wrt global_model 1.4459960102593332
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.78577, Val Fairness: -0.50000, Val Recall: 0.82569
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.78818, Val Fairness: -0.50000, Val Recall: 0.79618
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.78621, Val Fairness: -0.50000, Val Recall: 0.80934
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.78253, Val Fairness: -0.50000, Val Recall: 0.78866
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.78791, Val Fairness: -0.50000, Val Recall: 0.77477
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.79043, Val Fairness: -0.50000, Val Recall: 0.78577
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.78270, Val Fairness: -0.50000, Val Recall: 0.87227
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.78900, Val Fairness: -1.00000, Val Recall: 0.78895
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.78994, Val Fairness: -0.50000, Val Recall: 0.83683
# ======Validation========
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21932\960313446.py:242: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   weights = torch.tensor(self.weights_cache, device=self.device) / weight_sum_2
#  40%|████████████████████████████████                                                | 2/5 [04:45<07:12, 144.23s/it]
# Epoch 10/10, Val Accuracy: 0.78939, Val Fairness: -0.50000, Val Recall: 0.82323
# client_3 is updated and its fairness score wrt global_model -2.5415182546749775
#
#
#
# for round 1 , global fairness, accuracy, and recall are:  tensor(0.1606) ,  0.7840683283946314 ,  0.8620296465222349
#
#
#
# Before weights -2 (W/w)::  tensor([9.2950, 7.7095, 2.0885, 1.9320])
# After weights_::  tensor([8.4882, 6.9049, 1.2880, 1.1266])
# After weights_ Prob::  tensor([0.4767, 0.3877, 0.0723, 0.0633])
# round:: 2
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.81385, Val Fairness: 0.85714, Val Recall: 0.76689
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.81190, Val Fairness: 1.00000, Val Recall: 0.84419
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.82532, Val Fairness: 0.85714, Val Recall: 0.80341
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.81818, Val Fairness: 0.85714, Val Recall: 0.78758
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.82273, Val Fairness: 0.71429, Val Recall: 0.77480
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.81818, Val Fairness: 0.85714, Val Recall: 0.75776
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.81883, Val Fairness: 0.85714, Val Recall: 0.82045
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.82381, Val Fairness: 0.71429, Val Recall: 0.73524
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.81970, Val Fairness: 0.85714, Val Recall: 0.75411
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.81905, Val Fairness: 0.85714, Val Recall: 0.80645
# client_0 is updated and its fairness score wrt global_model 2.329660238751148
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.79891, Val Fairness: -0.80000, Val Recall: 0.77837
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.80546, Val Fairness: -0.80000, Val Recall: 0.80493
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.80073, Val Fairness: -0.72000, Val Recall: 0.80155
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.79527, Val Fairness: -0.88000, Val Recall: 0.82038
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.80237, Val Fairness: -0.76000, Val Recall: 0.78561
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.79782, Val Fairness: -0.76000, Val Recall: 0.78899
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.80237, Val Fairness: -0.72000, Val Recall: 0.74988
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.80164, Val Fairness: -0.84000, Val Recall: 0.76678
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.80455, Val Fairness: -0.80000, Val Recall: 0.78996
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.80073, Val Fairness: -0.72000, Val Recall: 0.74843
# client_1 is updated and its fairness score wrt global_model -1.6635392212418034
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.81484, Val Fairness: 0.63636, Val Recall: 0.73057
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.83615, Val Fairness: 0.81818, Val Recall: 0.83574
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.83829, Val Fairness: 0.81818, Val Recall: 0.83011
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.82518, Val Fairness: 0.63636, Val Recall: 0.76195
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.83754, Val Fairness: 0.90909, Val Recall: 0.84151
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.83280, Val Fairness: 0.90909, Val Recall: 0.78745
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.83483, Val Fairness: 0.54545, Val Recall: 0.80314
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.83217, Val Fairness: 0.63636, Val Recall: 0.78978
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.83939, Val Fairness: 0.81818, Val Recall: 0.82667
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.83766, Val Fairness: 0.72727, Val Recall: 0.81209
# client_2 is updated and its fairness score wrt global_model 1.285329786897185
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.79174, Val Fairness: -0.50000, Val Recall: 0.82367
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.78286, Val Fairness: -0.50000, Val Recall: 0.85751
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.79273, Val Fairness: -1.00000, Val Recall: 0.81759
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.78560, Val Fairness: -0.50000, Val Recall: 0.84435
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.79481, Val Fairness: -0.50000, Val Recall: 0.77969
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.78358, Val Fairness: -1.00000, Val Recall: 0.86952
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.79268, Val Fairness: -0.50000, Val Recall: 0.76277
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.79180, Val Fairness: -0.50000, Val Recall: 0.81383
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.79240, Val Fairness: -0.50000, Val Recall: 0.80616
# ======Validation========
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21932\960313446.py:242: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   weights = torch.tensor(self.weights_cache, device=self.device) / weight_sum_2
#  60%|████████████████████████████████████████████████                                | 3/5 [07:23<05:00, 150.27s/it]
# Epoch 10/10, Val Accuracy: 0.79158, Val Fairness: -0.50000, Val Recall: 0.82670
# client_3 is updated and its fairness score wrt global_model -2.5415182546749775
#
#
#
# for round 2 , global fairness, accuracy, and recall are:  tensor(0.3976) ,  0.7973156702109117 ,  0.8343785632839225
#
#
#
# Before weights -2 (W/w)::  tensor([8.4882, 6.9049, 1.2880, 1.1266])
# After weights_::  tensor([7.6761, 6.0952, 0.4778, 0.3123])
# After weights_ Prob::  tensor([0.5272, 0.4186, 0.0328, 0.0214])
# round:: 3
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.82424, Val Fairness: 0.85714, Val Recall: 0.81802
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.81926, Val Fairness: 0.85714, Val Recall: 0.79854
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.82532, Val Fairness: 0.85714, Val Recall: 0.83628
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.82706, Val Fairness: 0.85714, Val Recall: 0.80341
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.81255, Val Fairness: 0.85714, Val Recall: 0.68411
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.82684, Val Fairness: 0.85714, Val Recall: 0.78576
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.82229, Val Fairness: 0.85714, Val Recall: 0.81741
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.82597, Val Fairness: 0.85714, Val Recall: 0.78758
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.81602, Val Fairness: 0.85714, Val Recall: 0.77358
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.82013, Val Fairness: 0.71429, Val Recall: 0.76932
# client_0 is updated and its fairness score wrt global_model 1.9413835322926234
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.79854, Val Fairness: -0.80000, Val Recall: 0.79430
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.79854, Val Fairness: -0.76000, Val Recall: 0.78851
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.80000, Val Fairness: -0.80000, Val Recall: 0.78947
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.80291, Val Fairness: -0.84000, Val Recall: 0.79141
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.80164, Val Fairness: -0.84000, Val Recall: 0.80637
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.80346, Val Fairness: -0.80000, Val Recall: 0.79720
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.80473, Val Fairness: -0.80000, Val Recall: 0.78513
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.80000, Val Fairness: -0.80000, Val Recall: 0.79237
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.80127, Val Fairness: -0.76000, Val Recall: 0.77789
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.79891, Val Fairness: -0.88000, Val Recall: 0.83390
# client_1 is updated and its fairness score wrt global_model -2.033214603739982
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.83355, Val Fairness: 0.72727, Val Recall: 0.80559
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.83540, Val Fairness: 0.63636, Val Recall: 0.80253
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.83800, Val Fairness: 0.81818, Val Recall: 0.84347
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.83373, Val Fairness: 0.63636, Val Recall: 0.78524
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.83552, Val Fairness: 0.63636, Val Recall: 0.79603
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.82749, Val Fairness: 0.63636, Val Recall: 0.75925
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.83812, Val Fairness: 0.72727, Val Recall: 0.79860
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.83979, Val Fairness: 0.81818, Val Recall: 0.81809
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.82281, Val Fairness: 0.63636, Val Recall: 0.74332
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.84055, Val Fairness: 0.63636, Val Recall: 0.82753
# client_2 is updated and its fairness score wrt global_model 1.1246635635350368
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.79279, Val Fairness: -0.50000, Val Recall: 0.77926
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.79306, Val Fairness: -0.50000, Val Recall: 0.77607
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.79618, Val Fairness: -0.50000, Val Recall: 0.79936
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.79394, Val Fairness: -1.00000, Val Recall: 0.81745
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.79103, Val Fairness: -0.50000, Val Recall: 0.81383
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.79531, Val Fairness: -0.50000, Val Recall: 0.80486
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.79465, Val Fairness: -0.50000, Val Recall: 0.81730
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.79290, Val Fairness: -0.50000, Val Recall: 0.79994
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.79525, Val Fairness: -1.00000, Val Recall: 0.84609
# ======Validation========
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21932\960313446.py:242: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   weights = torch.tensor(self.weights_cache, device=self.device) / weight_sum_2
#  80%|████████████████████████████████████████████████████████████████                | 4/5 [10:12<02:37, 157.73s/it]
# Epoch 10/10, Val Accuracy: 0.79229, Val Fairness: -0.50000, Val Recall: 0.82685
# client_3 is updated and its fairness score wrt global_model -2.5415182546749775
#
#
#
# for round 3 , global fairness, accuracy, and recall are:  tensor(0.1547) ,  0.7989541572250305 ,  0.8339034587609274
#
#
#
# Before weights -2 (W/w)::  tensor([7.6761, 6.0952, 0.4778, 0.3123])
# After weights_::  tensor([ 6.8580,  5.2787, -0.3351, -0.5052])
# After weights_ Prob::  tensor([ 0.6071,  0.4673, -0.0297, -0.0447])
# round:: 4
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.81926, Val Fairness: 0.85714, Val Recall: 0.84540
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.82078, Val Fairness: 0.85714, Val Recall: 0.80097
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.81710, Val Fairness: 0.71429, Val Recall: 0.80341
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.82338, Val Fairness: 0.85714, Val Recall: 0.83688
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.81970, Val Fairness: 0.85714, Val Recall: 0.81376
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.82035, Val Fairness: 0.71429, Val Recall: 0.78637
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.81883, Val Fairness: 0.85714, Val Recall: 0.82045
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.82597, Val Fairness: 0.71429, Val Recall: 0.76872
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.82597, Val Fairness: 0.85714, Val Recall: 0.80402
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.82056, Val Fairness: 0.85714, Val Recall: 0.79428
# client_0 is updated and its fairness score wrt global_model 2.329660238751148
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.80564, Val Fairness: -0.80000, Val Recall: 0.80734
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.80055, Val Fairness: -0.88000, Val Recall: 0.83003
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.80200, Val Fairness: -0.84000, Val Recall: 0.79575
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.80127, Val Fairness: -0.76000, Val Recall: 0.76340
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.80400, Val Fairness: -0.80000, Val Recall: 0.80348
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.80018, Val Fairness: -0.76000, Val Recall: 0.74988
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.80382, Val Fairness: -0.80000, Val Recall: 0.78996
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.80473, Val Fairness: -0.72000, Val Recall: 0.76292
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.80601, Val Fairness: -0.76000, Val Recall: 0.75761
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.80182, Val Fairness: -0.92000, Val Recall: 0.80444
# client_1 is updated and its fairness score wrt global_model -2.125633449364527
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.83286, Val Fairness: 0.72727, Val Recall: 0.79468
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.84031, Val Fairness: 0.81818, Val Recall: 0.84028
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.83789, Val Fairness: 0.72727, Val Recall: 0.79443
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.84049, Val Fairness: 0.81818, Val Recall: 0.81172
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.83332, Val Fairness: 0.81818, Val Recall: 0.78058
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.83379, Val Fairness: 0.63636, Val Recall: 0.78218
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.83916, Val Fairness: 0.81818, Val Recall: 0.84947
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.83667, Val Fairness: 0.72727, Val Recall: 0.79149
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.84014, Val Fairness: 0.63636, Val Recall: 0.81809
# ======Validation========
# Epoch 10/10, Val Accuracy: 0.83910, Val Fairness: 0.72727, Val Recall: 0.81723
# client_2 is updated and its fairness score wrt global_model 1.285329786897185
#
#
#
# ======Validation========
# Epoch 1/10, Val Accuracy: 0.79509, Val Fairness: -1.00000, Val Recall: 0.82063
# ======Validation========
# Epoch 2/10, Val Accuracy: 0.78873, Val Fairness: -0.50000, Val Recall: 0.84522
# ======Validation========
# Epoch 3/10, Val Accuracy: 0.79301, Val Fairness: -1.00000, Val Recall: 0.84999
# ======Validation========
# Epoch 4/10, Val Accuracy: 0.79383, Val Fairness: -0.50000, Val Recall: 0.78360
# ======Validation========
# Epoch 5/10, Val Accuracy: 0.79279, Val Fairness: -1.00000, Val Recall: 0.82526
# ======Validation========
# Epoch 6/10, Val Accuracy: 0.79591, Val Fairness: -1.00000, Val Recall: 0.78548
# ======Validation========
# Epoch 7/10, Val Accuracy: 0.79268, Val Fairness: -0.50000, Val Recall: 0.82714
# ======Validation========
# Epoch 8/10, Val Accuracy: 0.79476, Val Fairness: -0.50000, Val Recall: 0.82193
# ======Validation========
# Epoch 9/10, Val Accuracy: 0.79021, Val Fairness: -1.00000, Val Recall: 0.83480
# ======Validation========
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21932\960313446.py:242: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   weights = torch.tensor(self.weights_cache, device=self.device) / weight_sum_2
# 100%|████████████████████████████████████████████████████████████████████████████████| 5/5 [13:10<00:00, 158.00s/it]
# Epoch 10/10, Val Accuracy: 0.79443, Val Fairness: -1.00000, Val Recall: 0.84305
# client_3 is updated and its fairness score wrt global_model -5.083036509349955
#
#
#
# for round 4 , global fairness, accuracy, and recall are:  tensor(0.6102) ,  0.7974202544884086 ,  0.8280121626757887
#
#
#
# Before weights -2 (W/w)::  tensor([ 6.8580,  5.2787, -0.3351, -0.5052])
# After weights_::  tensor([ 6.0417,  4.4642, -1.1471, -1.3250])
# After weights_ Prob::  tensor([ 0.7520,  0.5557, -0.1428, -0.1649])

# %%
 # client_acc [0.621039359719329, 0.621039359719329, 0.621039359719329, 0.621039359719329]
 # client_acc [0.7801227935533385, 0.7802324306545335, 0.7809998903628989, 0.7817810547089135]

# %%
sum([0.4361, 0.3636, 0.1037, 0.0966])
